# %%
import os
import requests
import pandas as pd
import numpy as np
from tabula import read_pdf
from selenium import webdriver
from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support.ui import Select

# %%
# https://itmdapps.milwaukee.gov/publicApplication_SR/censusTractfm.jsp

opts = Options()
# opts.set_headless()
# assert opts.headless  # operating in headless mode
path = r"C:/Users/marie/Documents/_AdvancedDataScience/MKECrimeModel/geckodriver.exe"

browser = Firefox(executable_path=path, options=opts)
browser.get('https://itmdapps.milwaukee.gov/publicApplication_SR/censusTractfm.jsp')

# %%
# get and save all needed pdfs of census tract data
dropdown = browser.find_element_by_name('CensusTracts')
censusTracts = [x.get_attribute("value") for x in dropdown.find_elements_by_tag_name("option")]
for tract in censusTracts:
    url = "https://itmdapps.milwaukee.gov/publicApplication_SR/CensusTractServlet?CensusTracts=%s&fromDate=01%%2F01%%2F2005&toDate=01%%2F01%%2F2016&submit=Submit" % (tract)
    r = requests.get(url, allow_redirects=True)
    fileName = './data/CensusTracts/tract%s.pdf' % (tract)
    open(fileName, 'wb').write(r.content)
    print(fileName)
    
#search_form = browser.find_element_by_id('search_form_input_homepage')
#search_form = browser.find_element_by_name('CensusTracts')    
    
#dropdown = Select(browser.find_element_by_name('CensusTracts'))
#dropdown.select_by_value('201')

#fromDateBox = browser.find_element_by_name('fromDate')
#fromDateBox.send_keys('01/01/2005')
#toDateBox = browser.find_element_by_name('toDate')
#toDateBox.send_keys('01/01/2016')

#submitButton = browser.find_element_by_name('submit')
#submitButton.click()

#results = browser.find_elements_by_class_name('result')
#print(results)

#browser.close()
#quit()
#censusTracts
# Out:
# ./data/CensusTracts/tract101.pdf
# ./data/CensusTracts/tract102.pdf
# ./data/CensusTracts/tract201.pdf
# ./data/CensusTracts/tract202.pdf
# ./data/CensusTracts/tract301.pdf
# ./data/CensusTracts/tract302.pdf
# ./data/CensusTracts/tract303.pdf
# ./data/CensusTracts/tract304.pdf
# ./data/CensusTracts/tract400.pdf
# ./data/CensusTracts/tract501.pdf
# ./data/CensusTracts/tract502.pdf
# ./data/CensusTracts/tract600.pdf
# ./data/CensusTracts/tract700.pdf
# ./data/CensusTracts/tract800.pdf
# ./data/CensusTracts/tract900.pdf
# ./data/CensusTracts/tract1000.pdf
# ./data/CensusTracts/tract1100.pdf
# ./data/CensusTracts/tract1200.pdf
# ./data/CensusTracts/tract1300.pdf
# ./data/CensusTracts/tract1400.pdf
# ./data/CensusTracts/tract1500.pdf
# ./data/CensusTracts/tract1600.pdf
# ./data/CensusTracts/tract1700.pdf
# ./data/CensusTracts/tract1800.pdf
# ./data/CensusTracts/tract1900.pdf
# ./data/CensusTracts/tract2000.pdf
# ./data/CensusTracts/tract2100.pdf
# ./data/CensusTracts/tract2200.pdf
# ./data/CensusTracts/tract2300.pdf
# ./data/CensusTracts/tract2400.pdf
# ./data/CensusTracts/tract2500.pdf
# ./data/CensusTracts/tract2600.pdf
# ./data/CensusTracts/tract2700.pdf
# ./data/CensusTracts/tract2800.pdf
# ./data/CensusTracts/tract2900.pdf
# ./data/CensusTracts/tract3000.pdf
# ./data/CensusTracts/tract3100.pdf
# ./data/CensusTracts/tract3200.pdf
# ./data/CensusTracts/tract3300.pdf
# ./data/CensusTracts/tract3400.pdf
# ./data/CensusTracts/tract3500.pdf
# ./data/CensusTracts/tract3600.pdf
# ./data/CensusTracts/tract3700.pdf
# ./data/CensusTracts/tract3800.pdf
# ./data/CensusTracts/tract3900.pdf
# ./data/CensusTracts/tract4000.pdf
# ./data/CensusTracts/tract4100.pdf
# ./data/CensusTracts/tract4200.pdf
# ./data/CensusTracts/tract4300.pdf
# ./data/CensusTracts/tract4400.pdf
# ./data/CensusTracts/tract4500.pdf
# ./data/CensusTracts/tract4600.pdf
# ./data/CensusTracts/tract4700.pdf
# ./data/CensusTracts/tract4800.pdf
# ./data/CensusTracts/tract4900.pdf
# ./data/CensusTracts/tract5000.pdf
# ./data/CensusTracts/tract5100.pdf
# ./data/CensusTracts/tract5200.pdf
# ./data/CensusTracts/tract5300.pdf
# ./data/CensusTracts/tract5400.pdf
# ./data/CensusTracts/tract5500.pdf
# ./data/CensusTracts/tract5600.pdf
# ./data/CensusTracts/tract5700.pdf
# ./data/CensusTracts/tract5800.pdf
# ./data/CensusTracts/tract5900.pdf
# ./data/CensusTracts/tract6000.pdf
# ./data/CensusTracts/tract6100.pdf
# ./data/CensusTracts/tract6200.pdf
# ./data/CensusTracts/tract6300.pdf
# ./data/CensusTracts/tract6400.pdf
# ./data/CensusTracts/tract6500.pdf
# ./data/CensusTracts/tract6600.pdf
# ./data/CensusTracts/tract6700.pdf
# ./data/CensusTracts/tract6800.pdf
# ./data/CensusTracts/tract6900.pdf
# ./data/CensusTracts/tract7000.pdf
# ./data/CensusTracts/tract7100.pdf
# ./data/CensusTracts/tract7200.pdf
# ./data/CensusTracts/tract7300.pdf
# ./data/CensusTracts/tract7400.pdf
# ./data/CensusTracts/tract7500.pdf
# ./data/CensusTracts/tract7600.pdf
# ./data/CensusTracts/tract7700.pdf
# ./data/CensusTracts/tract7800.pdf
# ./data/CensusTracts/tract7900.pdf
# ./data/CensusTracts/tract8000.pdf
# ./data/CensusTracts/tract8100.pdf
# ./data/CensusTracts/tract8400.pdf
# ./data/CensusTracts/tract8500.pdf
# ./data/CensusTracts/tract8600.pdf
# ./data/CensusTracts/tract8700.pdf
# ./data/CensusTracts/tract8800.pdf
# ./data/CensusTracts/tract8900.pdf
# ./data/CensusTracts/tract9000.pdf
# ./data/CensusTracts/tract9100.pdf
# ./data/CensusTracts/tract9200.pdf
# ./data/CensusTracts/tract9300.pdf
# ./data/CensusTracts/tract9400.pdf
# ./data/CensusTracts/tract9500.pdf
# ./data/CensusTracts/tract9600.pdf
# ./data/CensusTracts/tract9700.pdf
# ./data/CensusTracts/tract9800.pdf
# ./data/CensusTracts/tract9900.pdf
# ./data/CensusTracts/tract10600.pdf
# ./data/CensusTracts/tract10700.pdf
# ./data/CensusTracts/tract10800.pdf
# ./data/CensusTracts/tract11000.pdf
# ./data/CensusTracts/tract11100.pdf
# ./data/CensusTracts/tract11200.pdf
# ./data/CensusTracts/tract11300.pdf
# ./data/CensusTracts/tract11400.pdf
# ./data/CensusTracts/tract12200.pdf
# ./data/CensusTracts/tract12300.pdf
# ./data/CensusTracts/tract12400.pdf
# ./data/CensusTracts/tract12500.pdf
# ./data/CensusTracts/tract12600.pdf
# ./data/CensusTracts/tract12700.pdf
# ./data/CensusTracts/tract12800.pdf
# ./data/CensusTracts/tract12900.pdf
# ./data/CensusTracts/tract13000.pdf
# ./data/CensusTracts/tract13300.pdf
# ./data/CensusTracts/tract13400.pdf
# ./data/CensusTracts/tract13500.pdf
# ./data/CensusTracts/tract13600.pdf
# ./data/CensusTracts/tract13700.pdf
# ./data/CensusTracts/tract14100.pdf
# ./data/CensusTracts/tract14300.pdf
# ./data/CensusTracts/tract14400.pdf
# ./data/CensusTracts/tract14600.pdf
# ./data/CensusTracts/tract14700.pdf
# ./data/CensusTracts/tract14800.pdf
# ./data/CensusTracts/tract14900.pdf
# ./data/CensusTracts/tract15700.pdf
# ./data/CensusTracts/tract15800.pdf
# ./data/CensusTracts/tract15900.pdf
# ./data/CensusTracts/tract16000.pdf
# ./data/CensusTracts/tract16100.pdf
# ./data/CensusTracts/tract16200.pdf
# ./data/CensusTracts/tract16300.pdf
# ./data/CensusTracts/tract16400.pdf
# ./data/CensusTracts/tract16500.pdf
# ./data/CensusTracts/tract16600.pdf
# ./data/CensusTracts/tract16700.pdf
# ./data/CensusTracts/tract16800.pdf
# ./data/CensusTracts/tract16900.pdf
# ./data/CensusTracts/tract17000.pdf
# ./data/CensusTracts/tract17100.pdf
# ./data/CensusTracts/tract17200.pdf
# ./data/CensusTracts/tract17300.pdf
# ./data/CensusTracts/tract17400.pdf
# ./data/CensusTracts/tract17500.pdf
# ./data/CensusTracts/tract17600.pdf
# ./data/CensusTracts/tract17900.pdf
# ./data/CensusTracts/tract18000.pdf
# ./data/CensusTracts/tract18100.pdf
# ./data/CensusTracts/tract18200.pdf
# ./data/CensusTracts/tract18300.pdf
# ./data/CensusTracts/tract18400.pdf
# ./data/CensusTracts/tract18500.pdf
# ./data/CensusTracts/tract18600.pdf
# ./data/CensusTracts/tract18700.pdf
# ./data/CensusTracts/tract18800.pdf
# ./data/CensusTracts/tract18900.pdf
# ./data/CensusTracts/tract19000.pdf
# ./data/CensusTracts/tract19100.pdf
# ./data/CensusTracts/tract19200.pdf
# ./data/CensusTracts/tract19300.pdf
# ./data/CensusTracts/tract19400.pdf
# ./data/CensusTracts/tract19500.pdf
# ./data/CensusTracts/tract19600.pdf
# ./data/CensusTracts/tract19700.pdf
# ./data/CensusTracts/tract19800.pdf
# ./data/CensusTracts/tract19900.pdf
# ./data/CensusTracts/tract20000.pdf
# ./data/CensusTracts/tract20100.pdf
# ./data/CensusTracts/tract20200.pdf
# ./data/CensusTracts/tract20300.pdf
# ./data/CensusTracts/tract20400.pdf
# ./data/CensusTracts/tract20500.pdf
# ./data/CensusTracts/tract20600.pdf
# ./data/CensusTracts/tract20700.pdf
# ./data/CensusTracts/tract20800.pdf
# ./data/CensusTracts/tract20900.pdf
# ./data/CensusTracts/tract21000.pdf
# ./data/CensusTracts/tract21100.pdf
# ./data/CensusTracts/tract21200.pdf
# ./data/CensusTracts/tract21300.pdf
# ./data/CensusTracts/tract21400.pdf
# ./data/CensusTracts/tract21500.pdf
# ./data/CensusTracts/tract21600.pdf
# ./data/CensusTracts/tract21700.pdf
# ./data/CensusTracts/tract21800.pdf
# ./data/CensusTracts/tract160100.pdf
# ./data/CensusTracts/tract185400.pdf
# ./data/CensusTracts/tract185500.pdf
# ./data/CensusTracts/tract185600.pdf
# ./data/CensusTracts/tract185700.pdf
# ./data/CensusTracts/tract185800.pdf
# ./data/CensusTracts/tract185900.pdf
# ./data/CensusTracts/tract186000.pdf
# ./data/CensusTracts/tract186100.pdf
# ./data/CensusTracts/tract186200.pdf
# ./data/CensusTracts/tract186300.pdf
# ./data/CensusTracts/tract186400.pdf
# ./data/CensusTracts/tract186500.pdf
# ./data/CensusTracts/tract186600.pdf
# ./data/CensusTracts/tract186800.pdf
# ./data/CensusTracts/tract186900.pdf
# ./data/CensusTracts/tract187000.pdf
# ./data/CensusTracts/tract187400.pdf
# ./data/CensusTracts/tract200400.pdf
# ./data/CensusTracts/tract470201.pdf
# ./data/CensusTracts/tract980000.pdf

# %%
# Not the cleanest, but I just ran this 3 times for census, police and aldermanic districts

#df = pd.DataFrame(columns=dfCols)
dfCols = ['District', 'Type', 'Population', 'Area sqmi', 'Under 5', '5 to 17', '18 to 24', '25 to 44', '45 to 64', 'Over 65', 'Male', 'Female', 'Total Families', 'Avg Residential Value', 'Liquor Licenses', 'Faith Orgs', 'Parks', 'Total A Offenses', 'Assault Offenses', 'Arson', 'Burglary', 'Criminal Damages', 'Locked Vehicle', 'Robbery', 'Sex Offense', 'Theft', 'Vehicle Theft', 'Homicide']

#pathToPDFs = '../data/CensusTracts/'
#pathToPDFs = '../data/PolicePDFs/'
pathToPDFs = '../data/Aldermanic/'
pdfLists = os.listdir(pathToPDFs)
for pdf in pdfLists:
    print(pdf)
    demoDF = read_pdf(pathToPDFs + pdf, pages='1-3')
    crimeDF = read_pdf(pathToPDFs + pdf, pages=4)
    
    #district = pdf.replace('tract', '').replace('.pdf', '')
    #distType = 'CensusTract'
    #district = pdf.replace('PoliceDistrict', '').replace('.pdf', '')
    #distType = 'PoliceDistrict'
    district = int(pdf.replace('AldermanicDistrict', '').replace('.pdf', ''))
    distType = 'AldermanicDistrict'
    
    
    population = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Total Population', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    area = float(demoDF.loc[demoDF['Unnamed: 0'] == 'Area (Square miles)', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    under5 = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Under 5 years', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    between5and17 = int(demoDF.loc[demoDF['Unnamed: 0'] == '5 to 17 years', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    between18and24 = int(demoDF.loc[demoDF['Unnamed: 0'] == '18 to 24 years', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    between25and44 = int(demoDF.loc[demoDF['Unnamed: 0'] == '25 to 44 years', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    between45and64 = int(demoDF.loc[demoDF['Unnamed: 0'] == '45 to 64 years', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    over65 = int(demoDF.loc[demoDF['Unnamed: 0'] == '65 years and over', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    male = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Male', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    female = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Female', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    families = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Total families', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    residentialValue = float(demoDF.loc[demoDF['Unnamed: 0'] == 'Average Assessed Residential Value (current)', demoDF.columns[1]].values[0].split(' ')[0].replace(',', '').replace('$', ''))
    liquorLicenses = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Total Liquor Licenses', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    faithOrgs = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Faith Based Organizations', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    parks = int(demoDF.loc[demoDF['Unnamed: 0'] == 'Parks', demoDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    
    totalAOffenses = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Total Summary WIBR for specific group A offenses', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    assault = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Assault Offenses', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    arson = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Arson', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    burglary = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Burglary', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    criminalDamages = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Criminal Damage', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    lockedVehicle = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Locked Vehicle', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    robbery = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Robbery', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    sexOffense = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Sex Offense', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    theft = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Theft', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    vehicleTheft = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Vehicle Theft', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    homicide = int(crimeDF.loc[crimeDF['Unnamed: 0'] == 'Homicide', crimeDF.columns[1]].values[0].split(' ')[0].replace(',', ''))
    
    row = pd.DataFrame([[district, distType, population, area, \
                        under5, between5and17, between18and24, between25and44, between45and64, over65, \
                        male, female, families, \
                        residentialValue, liquorLicenses, faithOrgs, parks, \
                        totalAOffenses, assault, arson, burglary, criminalDamages, \
                        lockedVehicle, robbery, sexOffense, theft, vehicleTheft, homicide]], 
                       columns = dfCols)
    df = df.append(row)
# Out:
# AldermanicDistrict1.pdf
# AldermanicDistrict10.pdf
# AldermanicDistrict11.pdf
# AldermanicDistrict12.pdf
# AldermanicDistrict13.pdf
# AldermanicDistrict14.pdf
# AldermanicDistrict15.pdf
# AldermanicDistrict2.pdf
# AldermanicDistrict3.pdf
# AldermanicDistrict4.pdf
# AldermanicDistrict5.pdf
# AldermanicDistrict6.pdf
# AldermanicDistrict7.pdf
# AldermanicDistrict8.pdf
# AldermanicDistrict9.pdf

# %%
df.to_csv('../data/CensusPoliceAldermanicData.csv', index=False)
